# %%
print("Let's Master ML 0-100% Complete")
# Out:
# Let's Master ML 0-100% Complete

# %%
# import pandas as pd
# import random

# # Generate random subtraction data
# data = {'Number 1': [random.randint(1, 50) for _ in range(1, 19)],
#         'Number 2': [random.randint(1, 50) for _ in range(1, 19)],
#         'Result': []}

# # Calculate the result of subtraction for each pair
# for i in range(18):
#     data['Result'].append(data['Number 1'][i] - data['Number 2'][i])

# # Create the DataFrame
# df_subtraction = pd.DataFrame(data)

# # Save the DataFrame to CSV
# df_subtraction.to_csv('../data/subtraction_data.csv', index=False)

# print("Subtraction CSV file created successfully.")

# %%
df = pd.read_csv('../data/subtraction_data.csv')
df
# Out:
#     Number 1  Number 2  Result
# 0         43         6    37.0
# 1         35        18    17.0
# 2         39        45    -6.0
# 3         44        37     7.0
# 4          9        30   -21.0
# 5         21        28    -7.0
# 6          8        17    -9.0
# 7         10         8     2.0
# 8         38        39    -1.0
# 9         11        35   -24.0
# 10        38        24     NaN
# 11         9        12    -3.0
# 12        19        46   -27.0
# 13        50        11    39.0
# 14        13        14    -1.0
# 15        18        21    -3.0
# 16        47        49    -2.0
# 17        22         6    16.0

# %%
df.dtypes
# Out:
# Number 1      int64
# Number 2      int64
# Result      float64
# dtype: object

# %%
df.isna().sum()
df.dropna(inplace=True)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df[['Number 1', 'Number 2']] 
y = df['Result']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=42)

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()

model.fit(X_train, y_train)

y_pred = model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# Make predictions on the test set
y_pred = model.predict(X_test)

# # Calculate accuracy
# accuracy = accuracy_score(y_test, y_pred)
# print(f'Accuracy: {accuracy}')

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Print the results
print(f'Mean Absolute Error: {mae}')
print(f'Mean Squared Error: {mse}')
print(f'R-squared (R²): {r2}')
# Out:
# Mean Absolute Error: 1.0658141036401503e-14
# Mean Squared Error: 1.262177448353619e-28
# R-squared (R²): 1.0

# %%
import numpy as np

new_data = np.array([[24, 22]])

# Predict the class for the new data point
new_prediction = model.predict(new_data)
print(f"Predicted class: {new_prediction}")
# Out:
# Predicted class: [2.]
# /Users/shashankr/Development/Artificial Intelligence Projects/Zogle Labs/Learning Projects/Master-Learning/master-env/lib/python3.12/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
